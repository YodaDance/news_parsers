# %%
import time
import numpy as np
import pandas as pd
import pickle
import datetime

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import json
import dateparser

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('headless')    
service = Service('./chromedriver')
driver = webdriver.Chrome(service=service, options=options)

# %%
class KommersantParser:
    '''Парсит коммерсант по конкректному региону
    driver - selenium.webdriver, который будете использовать
    day - дата, с какой будем начинать выкачивать новости
    interval: 1 - за день, 2 - новости за неделю, 3 - за месяц с сегодняшней даты
    По умолчанию качает понедельно (interval=week), по региону Урал (region=66), начиная с сегодня'''

    intervals = {'day': '1', 'week': '2', 'month': '3'}

    def __init__(self, driver: webdriver, interval='week', region=66, day=datetime.datetime.today()):
        self.driver = driver
        self.interval = str(interval)
        self.region = str(region)
        self.day = day
    
    
    def __get_page_content(self, api: str) -> BeautifulSoup:
        '''Открывает ссылку, парсит html'''
        while True:
            try:
                self.driver.get(api) # открываем ссылку
                time.sleep(1) # даем прогрузиться
                break
            except TimeoutException:
                time.sleep(2)
                continue
        page_source = self.driver.page_source # берем страницу
        soup = BeautifulSoup(page_source, 'lxml') # парсим

        return soup


    def __get_article(self, link: str) -> str:
        '''Открывает страничку статьи, собирает текст с нее'''

        soup = self.__get_page_content(link)
        # здесь лежит статья
        while True:
            try:
                article = soup.find('div', class_='doc__body article_text_wrapper js-search-mark')
                ps = article.find_all('p', class_='doc__text') # собираем все аттрибуты p
                break
            except AttributeError:
                continue
        # две последние строчки в ps содержат слова подпишитесь и имя автора, они нам не нужны
        text = ''.join([p.text for p in ps[0:len(ps)-2]]).strip() 

        return text
        
    

    def __parse_first_page(self, soup: BeautifulSoup) -> list:
        '''Возвращает список собранных новостей с распрасенной страницы'''

        news = []

        rubrics = soup.find_all('article', class_='uho rubric_lenta__item js-article') # аттрибут новости
        for rubric in rubrics:
            cur_news = {}
            cur_news['description'] = rubric['data-article-description']
            cur_news['news_id'] = rubric['data-article-docsid']
            cur_news['title'] = rubric['data-article-title']
            cur_news['url'] = rubric['data-article-url']
            # дата
            news_date = dateparser.parse(rubric.find('p', class_='uho__tag rubric_lenta__item_tag hide_desktop').text)
            cur_news['published_date'] = news_date
            cur_news['text'] = self.__get_article(cur_news['url'])
            news.append(cur_news)

        return news
        
    
    def open_first_page(self) -> list:
        '''Открывает страницу архива новостей Коммерсанта с заданными вам параметрами из self, 
        возращает список собранных новостей'''

        today_for_starter_link = self.day.strftime('%Y-%m-%d')
        url = f'https://www.kommersant.ru/archive/list/{self.region}/{self.interval}/{today_for_starter_link}'
        soup = self.__get_page_content(url)

        return self.__parse_first_page(soup)

    
    def __parse_lazy_downloads(self, items: json) -> list:
        '''парсит страничку lazydownloads, достает атрибуты, загружает текст каждой новости'''
        parsed_news = []
        
        for item in items:
            cur_news = {}
            cur_news['description'] = item['SubTitle']
            cur_news['news_id'] = item['DocsID']
            cur_news['title'] = item['Title']
            cur_news['url'] = 'https://www.kommersant.ru/doc/' + str(item['DocsID'])
            cur_news['published_date'] = pd.to_datetime(item['DateDoc'], unit='s')
            cur_news['text'] = self.__get_article(cur_news['url'])
            parsed_news.append(cur_news)

        return parsed_news

        
    
    def __lazy_downloads(self, news: list, last_date: str) -> json:
        '''Делает запрос на lazydownloads с последней новости, 
        на которой остановился список выкачанных новостей, либо на последней со стратовой страницы.
        Возвращает обновленный список и отдельно состояние has_next_page, чтобы итерироваться'''

        last_id = news[-1]['news_id']
        url = f'https://www.kommersant.ru/archive/list/lazyloaddocs?regionid={self.region}&date={last_date}&intervaltype={self.intervals[self.interval]}&idafter={last_id}'
        soup = self.__get_page_content(url)
        data = json.loads(soup.text)
        news.extend(self.__parse_lazy_downloads(data['Items']))
        has_next_page = data['HasNextPage']

        return has_next_page

    
    def download_until_date(self, news: list, stop_date=datetime.datetime(2020,1,1)):
        '''Подгружает новости через lazydownloads до тех пор, пока не дойдет до стоп даты'''
        last_date = news[-1]['published_date'].date()
        stop_date = stop_date.date()
        
        while last_date >= stop_date:
            has_next_page = True
            while has_next_page:
                has_next_page = self.__lazy_downloads(news, last_date.strftime('%d.%m.%Y'))
            with open('kommersant', 'wb') as f:
                pickle.dump(news, f)
            print('Updated')
            last_date = news[-1]['published_date'].date()

        print(f'Update a file up to {stop_date.strftime("%d.%m.%Y")}')

# %%
parser = KommersantParser(driver=driver, interval='week', region=66)

# %%
#news = parser.open_first_page()
parser.download_until_date(news, stop_date=datetime.datetime(2020, 1, 1))
# Out:
# c:\Users\ska19\anaconda3\lib\site-packages\dateparser\date_parser.py:35: PytzUsageWarning: The localize method is no longer necessary, as this time zone supports the fold attribute (PEP 495). For more details on migrating to a PEP 495-compliant implementation, see https://pytz-deprecation-shim.readthedocs.io/en/latest/migration.html
#   date_obj = stz.localize(date_obj)

# %%
news
# Out:
# [{'description': '',
#   'news_id': '5423686',
#   'title': 'В «тюменской матрешке» подтвердили 41 новый случай COVID-19',
#   'url': 'https://www.kommersant.ru/doc/5423686',
#   'published_date': datetime.datetime(2022, 6, 22, 14, 48),
#   'text': 'За прошедшие сутки коронавирус выявили у 41 жителя Тюменской области, Ханты-Мансийского и Ямало-Ненецкого автономных округов, следует из данных сайта «Стопкоронавирус.рф». В Тюменской области диагностировали 25 случаев заражения. За все время пандемии инфекцию выявили у 191 984 жителей региона, из которых 187,4 тыс. – выздоровели, 4 335 – скончались. В ХМАО подтвердили коронавирусную инфекцию у 10 человек. Общее число заболевших составляет 211,1 тыс. Из них 208 389 пациентов уже выздоровели, 2 554 – умерли. На Ямале за сутки заразились шесть человек. С начала пандемии COVID-19 зафиксировали у 137 226 жителей. 135,8 тыс.– выздоровели, 1 042 – скончались.'},
#  {'description': '',
#   'news_id': '5423672',
#   'title': 'У банка «Солидарность» в Екатеринбурге собрались десятки желающих получить карту UnionPay',
#   'url': 'https://www.kommersant.ru/doc/5423672',
#   'published_date': datetime.datetime(2022, 6, 22, 14, 30),
#   'text': 'У отделения банка «Солидарность» на Красноармейской, 41 в Екатеринбурге собралась очередь из желающих получить карту UniopPay. Очередь формируют несколько человек, представившихся клиентами банка. Они составляют списки из желающих посетить отделение и не пускают клиентов внутрь. Двери в банк также закрыты. Сейчас у входа находятся около 30 человек, преимущественно выходцы из Китая и с Кавказа. Как рассказал «Ъ-Урал» один из тех, кто формирует очередь, решение составлять списки было принято из-за ажиотажа со стороны желающих оформить карту UnionPay. Очередь, по его словам, формируют все будущие клиенты, и они не являются сотрудниками банка. «Visa и MasterCard закрыли сейчас, а мы на рынках (торгуем.— "Ъ-Урал"), нам надо (оформить денежный) перевод в Китай, другие страны. А UnionPay только через это приложение можно»,— добавил он, уточнив, что «Солидарность» — единственный банк, выдающий карты UnionPay в Уральском федеральном округе. По данным сервиса «Банки.ру», в Екатеринбурге карты этой платежной системы также можно оформить в «МТС банке», в Газпромбанке также можно получить карту японской платежной системы JSB. «Смотри, сейчас в списке почти 80 человек. Прикинь, эти люди придут сейчас, что тут начнется?»,— рассказал «Ъ-Урал» мужчина, стоявший у закрытой двери отделения и указывающий, кто пойдет следующим. По его словам, клиенты формируют очереди таким образом уже около месяца. Когда корреспондент «Ъ-Урал» попытался пройти в банк, его остановили несколько стоявших перед дверью человек. Предварительно пришлось объяснить им, что он не является клиентом «Солидарности» и не планирует получать какие-либо услуги. После этого один из стоявших в очереди позвал охранника, который, посоветовавшись с сотрудниками, также отказал во входе и попросил обратиться в пресс-службу банка. Руководство отделения также не было на месте, добавил он. «Ъ-Урал» направил запрос в пресс-службу «Солидарности». Ранее об очередях сообщал и Е1 со ссылкой на одну из клиенток «Солидарности». По данным портала, формирующие очередь клиенты пытались взять с нее плату за вход в отделение. В разговоре с «Ъ-Урал» стоявшие в очереди в банк люди отрицали это. В пресс-службе банка порталу пояснили, что люди, стоящие у отделения, не имеют к нему отношения, а ситуация «доведена до нашего руководства, службы безопасности, службы финансового мониторинга и до соответствующих органов».Актуальность китайской платежной системы в России выросла после ухода из страны международных платежных систем Visa и MasterCard из-за военной спецоперации РФ на Украине. Карты этих платежных систем перестали работать за границей, в том числе при совершении покупок в иностранных онлайн-магазинах. Из МСП в России осталась только UnionPay — система работает в 180 странах, в том числе в США и ЕС. Сейчас возможность эмиссии таких карт имеют всего несколько российских банков.'},
#  {'description': '',
#   'news_id': '5423649',
#   'title': '«Уральские авиалинии» увеличат число рейсов из Екатеринбурга в Якутск',
#   'url': 'https://www.kommersant.ru/doc/5423649',
#   'published_date': datetime.datetime(2022, 6, 22, 13, 54),
#   'text': 'Авиакомпания «Уральские авиалинии» с 10 июля увеличит количество рейсов из Екатеринбурга в Якутск до пяти в неделю. В пресс-службе перевозчика сообщили, что перелеты будут осуществляться по понедельникам, по вторникам, средам, пятницам и субботам. Стоимость билетов — от 11 635 руб. Также будет увеличено число полетов в Якутск из Санкт-Петербурга.'},
#  {'description': '',
#   'news_id': '5423632',
#   'title': 'В Свердловской области за сутки подтвердили 91 новый случай COVID-19',
#   'url': 'https://www.kommersant.ru/doc/5423632',
#   'published_date': datetime.datetime(2022, 6, 22, 13, 30),
#   'text': 'За прошедшие сутки в Свердловской области коронавирусную инфекцию зафиксировали у 91 человека. По данным сервиса «Стопкоронавирус.рф», с начала пандемии выявили 446 861 случай заболевания. Из них 434,6 тыс. жителей выздоровели, 10 756 — скончались. С 19 июня количество заболевших в регионе не превышает отметки в 100 человек.'},
#  {'description': '',
#   'news_id': '5423605',
#   'title': 'СвЖД к маю 2023 года намерена создать выставочный передвижной эшелон «Эвакуация»',
#   'url': 'https://www.kommersant.ru/doc/5423605',
#   'published_date': datetime.datetime(2022, 6, 22, 12, 50),
#   'text': 'Свердловская железная дорога (СвЖД) начала подготовку проекта «Эвакуация» — передвижную выставку, которая будет посвящена эвакуации промышленных предприятий из европейской части страны на Урал в первые годы Великой Отечественной войны. «Впервые в стране мы создаем эшелон, на платформах которого разместятся станки и оборудование военного времени»,— рассказал начальник СвЖД Иван Колесников. Как сообщила пресс-служба СвЖД, сегодня в Каменске-Уральском прошла торжественная передача раритетных станков для будущего эшелона. В мероприятии приняли участие Иван Колесников, заместитель губернатора Свердловской области Алексей Шмыков, глава Каменска-Уральского Алексей Герасимов, директора предприятий. Иван Колесников напомнил, что в годы войны железная дорога выполняла беспрецедентный по масштабам объем перевозок. «В фантастически короткие сроки был перевезен в тыл и сохранен весь промышленный базис страны, культурные ценности, научные и рабочие кадры. Мы хотим рассказать молодому поколению, что такое эвакуация, насколько важна была ее роль в победе Советского Союза в Великой Отечественной войне»,— подчеркнул начальник СвЖД.Запуск проекта запланирован на май 2023 года.'},
#  {'description': '',
#   'news_id': '5423592',
#   'title': 'ФК «Урал» начнет новый сезон игрой против ЦСКА',
#   'url': 'https://www.kommersant.ru/doc/5423592',
#   'published_date': datetime.datetime(2022, 6, 22, 12, 36),
#   'text': 'В первом матче нового сезона Российской премьер-лиги (РПЛ) футбольный клуб «Урал» 15-17 июля сыграет в Москве с ЦСКА, сообщили в пресс-службе команды. Первый домашний мачт «Урал» проведет с 29 по 31 июля против ФК «Краснодар». В пресс-службе пояснили, что точные даты игр могут быть известны до конца недели.К новому сезону футбольный клуб заключил новые контракты с вратарем Ильей Помазуном, полузащитниками Олегом Шатовым, Фанилем Сунгатулиным и Игорем Коноваловым, нападающим Алексеем Каштановым. Напомним, что на фоне специальной военной операции России на Украине «Урал» покинули  украинский голкипер Ярослав Годзюр и польский полузащитник Рафал Августиняк. Ранее пресс-служба команды сообщила, что нападающий «Урала» Михаил Агеев перешел на правах аренды в ФК «Волгарь». По обоюдному согласию расторгли контракты с клубом форвард Владимир Ильин и защитник Доминик Динга.'},
#  {'description': '',
#   'news_id': '5423571',
#   'title': 'Брянского подростка будут судить за лжеминирование учреждений в Свердловской области',
#   'url': 'https://www.kommersant.ru/doc/5423571',
#   'published_date': datetime.datetime(2022, 6, 22, 12, 22),
#   'text': 'Следствие завершило расследование уголовного дела 16-летнего жителя поселка Клетня (Брянская область), обвиняемого в заведомо ложных сообщениях о минировании торгово-развлекательных центров и учебных заведений в регионах (ч. 3 ст. 207 УК РФ). Следствие считает, что он отправил 32 электронных письма с таким содержанием в МВД и ФСБ в девяти регионах, в том числе Свердловской области, а также Москвы, Санкт-Петербурга и Севастополя, сообщила пресс-служба брянского управления СКР. По версии следствия, сообщения были отправлены с 22 сентября по 20 октября 2020 года. В этом время молодой человек находился у себя дома в поселке Клетня. Для рассылки он использовал мобильный телефон, почтовое предложение и сервис анонимизации личности. «(Рассылка.— "Ъ-Урал") повлекла временную дестабилизацию деятельности оперативных служб, принявших участие в проведении антитеррористических и эвакуационных мероприятий, а также приостановку функционирования указанных коммерческих предприятий и учреждений образования»,— говорится в сообщении СКР. Подростка вычислили сотрудники УФСБ по Брянской области. Сейчас предварительное следствие завершено. Материалы направили в суд. Обвиняемому грозит лишение свободы вплоть до восьми лет.'},
#  {'description': '',
#   'news_id': '5423569',
#   'title': 'В Екатеринбурге закроют движение транспорта по улице Степана Разина',
#   'url': 'https://www.kommersant.ru/doc/5423569',
#   'published_date': datetime.datetime(2022, 6, 22, 12, 13),
#   'text': 'Движение транспорта по ул. Степана Разина в Екатеринбурге закроют с 22 июля по 5 августа, сообщили в пресс-службе мэрии. В этот период на участке будут проходить работы по строительству сетей водоснабжения, организованные МУП «Водоканал».'},
#  {'description': '',
#   'news_id': '5423566',
#   'title': 'Ученые УрФУ подобрали растения для озеленения почв с высоким содержанием меди',
#   'url': 'https://www.kommersant.ru/doc/5423566',
#   'published_date': datetime.datetime(2022, 6, 22, 12, 9),
#   'text': 'Ученые Уральского федерального университета (УрФУ) обнаружили растения, которые выживают в загрязненной почве, сообщили в пресс-службе вуза. Так, цинния (популярные декоративные цветы) и табак приспосабливаются к почве с высоким содержанием меди. Они накапливают тяжелый металл в корнях и не пропускают его в надземную часть растения: стебель, листья и далее. «На примере циннии мы впервые показали, что она может расти на почвах, загрязненных медью, и даже быстрее переходить к цветению, чем в чистых почвах. То есть ее можно использовать для озеленения территорий, и она будет хорошо расти. Табак, важная сельскохозяйственная культура, полезное удобрение, в наших экспериментах также адаптировался к длительному воздействию меди»,— рассказала младший научный сотрудник лаборатории «Биотехнологии поддержания и восстановления компонентов природных и трансформированных биосистем» УрФУ Анастасия Тугбаева.Ученые выявили эти особенности в ходе экспериментов, в которых воссоздали условия уровня влажности и температуры, характерные для региона, и проверяли влияние различных концентраций сульфата меди на рост растений и ряд физиолого-биохимических характеристик. «Мы проводили эксперименты в течение 20, 40, 60 дней и использовали субстраты, в которых содержание меди могло даже превышать ее содержание в почвах Екатеринбурга и окрестностей»,— пояснила Анастасия Тугбаева.Высокий уровень содержания меди в почвах особенно характерен для Свердловской и Челябинской областей — в городах присутствия предприятий медной промышленности. В опасную категорию загрязнения почв в Свердловской области входят Ревда и Кировград, в умеренно опасную категорию — Верхняя Пышма, Полевской и Первоуральск.'},
#  {'description': '',
#   'news_id': '5423519',
#   'title': 'Кандидат от ЛДПР подал документы на участие в выборах губернатора Свердловской области',
#   'url': 'https://www.kommersant.ru/doc/5423519',
#   'published_date': datetime.datetime(2022, 6, 22, 11, 5),
#   'text': 'Депутат законодательного собрания Свердловской области, координатор регионального отделения ЛДПР Александр Каптюг подал документы для участия в выборах губернатора региона, сообщил свердловский избирком.«Каптюг А. Н. выдвинут свердловским региональным отделением политической партии ЛДПР — Либерально-демократической партии России. Конференция по выдвижению состоялась 18 июня 2022 года»,— говорится в сообщении регионального избиркома в telegram-канале. Александр Каптюг родился в Могилеве (Беларусь) в 1978 году. В 1990-е работал тренером по дзюдо. После службы в армии в 1999 году перешел на работу в «ЛУКОЙЛ — Западная Сибирь». В 2002-2012 году работал в Южно-Уральской трубной компании, где прошел путь от менеджера по сбыто до генерального директора. Затем до 2021 года занимал должности директора и гендиректора в «Уральской производственной компании» и «Каслинском механическом предприятии» соответственно. Является членом комитета по региональной политики и развитию местного самоуправления свердловского заксобрания. Как ранее писал «Ъ-Урал», КПРФ — Александра Ивачева, «Справедливая Россия-За правду» — Андрея Кузнецова, «Единая Россия» — Евгения Куйвашева, «Новые люди» — Александра Демина.'},
#  {'description': '',
#   'news_id': '5423472',
#   'title': 'Прокуратура обжаловала УДО фотографа Лошагина, осужденного за убийство жены',
#   'url': 'https://www.kommersant.ru/doc/5423472',
#   'published_date': datetime.datetime(2022, 6, 22, 9, 45),
#   'text': 'Свердловская прокуратура обжаловала решение Чкаловского районного суда Екатеринбурга, одобрившего условно-досрочное освобождение (УДО) фотографа Дмитрия Лошагина, отбывающего наказание за убийство жены-модели Юлии Прокопьевой. Об этом сообщили в пресс-службе надзорного ведомства. По мнению прокуратуры, освобождение Дмитрия Лошагина является несправедливым, а вывод о его исправлении — необоснованный. В ведомстве добавили, что, согласно характеристике из колонии, его поведение оценивается лишь как удовлетворительное. Кроме того, фотограф до сих пор не раскаялся в содеянном. Прокуратура считает, что не может служить основанием для УДО и то, что осужденный на момент суда не имел действующих взысканий.«По мнению прокурора, Лошагин нуждается в дальнейшем отбывании наказания в местах лишения свободы, его УДО противоречит целям и задачам уголовного законодательства — исправление осужденных и восстановление социальной справедливости», — добавили в пресс-службе ведомства.Напомним, решение об УДО было принято 15 июня. В 2015 году фотограф был приговорен к девяти годам и десяти месяцам колонии за убийство жены модели Юлии Прокопьевой. Тогда суд установил, что в августе 2013 года фотограф поссорился с женой во время вечеринки в его фотостудии. Спускаясь с крыши здания и проходя через техническое помещение в студию, пьяный Лошагин напал на девушку и свернул ей шею. В итоге она скончалась на месте, а ночью фотограф вывез тело супруги в лес, где развел костер, накрыл труп фрагментами рубероида, облил голову девушки бензином и поджег, установили в суде.Отбыв большую часть срока, Дмитрий Лошагин начал просить суд об изменении наказания на ограничение свободы, а затем и об УДО. Так, летом 2021 года Чкаловский райсуд одобрил аналогичное ходатайство фотографа. Тогда против освобождения возразили прокуратура, руководство исправительного учреждения и родственники убитой. В конце сентября Свердловский облсуд отменил это решение и отправил дело на новое рассмотрение. Уже в октябре при повторном рассмотрении суд первой инстанции отказал фотографу в УДО.'},
#  {'description': '',
#   'news_id': '5423440',
#   'title': 'На трассе в Югре перевернулся автобус, три человека пострадали',
#   'url': 'https://www.kommersant.ru/doc/5423440',
#   'published_date': datetime.datetime(2022, 6, 22, 9, 4),
#   'text': 'Днем 21 июня на 84 км автодороги «Югра» в Ханты-Мансийском районе автобус съехал в кювет и перевернулся. Об этом сообщили в пресс-службе УГИБДД по Ханты-Мансийскому автономному округу (ХМАО). По предварительным данным, автобусом «Ютонг» управлял 35-летний мужчина, который неправильно расположил его на дороге и допустил съезд в кювет. В результате три пассажира получили травмы.'},
#  {'description': '',
#   'news_id': '5423436',
#   'title': 'Более 100 предпринимателей получили квалифицированную электронную подпись в офисах ВТБ в Екатеринбурге',
#   'url': 'https://www.kommersant.ru/doc/5423436',
#   'published_date': datetime.datetime(2022, 6, 22, 8, 58),
#   'text': 'Компании среднего и малого бизнеса могут получить в офисах ВТБ квалифицированный сертификат электронной подписи. В Екатеринбурге сервис запущен с марта, на сегодня им воспользовались свыше 100 предпринимателей.Банк ВТБ (ПАО) выдает КЭП в качестве доверенного лица Удостоверяющего центра ФНС России. Сейчас сервис доступен в отделениях банка в 40 городах страны. Получить КЭП могут все предприниматели, независимо от того, являются ли они клиентами банка.Сертификат электронной подписи записывается на сертифицированный защищенный физический носитель (USB-токен). Клиенту потребуются паспорт и один из документов  решение о назначении руководителя для юридического лица (или другой документ, подтверждающий право действовать от имени ЮЛ без доверенности) и лист записи ЕГРИП или свидетельство ОГРНИП – для ИП.'},
#  {'description': '',
#   'news_id': '5423430',
#   'title': 'В ходе спецоперации на Украине погиб лейтенант, служивший в Каменске-Уральском',
#   'url': 'https://www.kommersant.ru/doc/5423430',
#   'published_date': datetime.datetime(2022, 6, 22, 8, 42),
#   'text': 'Старший лейтенант Ильгизар Зиннуров из Башкирии погиб в ходе специальной военной операции на Украине. По данным E1.ru, он служил в воинской части в Каменске-Уральском (Свердловская область). Ильгизар Зиннуров окончил Челябинское высшее военное краснознаменное училище штурманов, был офицером боевого управления. «Ильгизар — настоящий герой, который посвятил свою жизнь служению Родине. Он до конца остался верным Военной присяге, погиб как настоящий герой, защищая Родину. Выражаю соболезнования родным, близким, знакомым», — написала во «ВКонтакте» глава администрации Кигинского района (Башкирия) Зухра Гордиенко.Похороны военного состоятся в селе Нижние Киги.'},
#  {'description': '',
#   'news_id': '5423401',
#   'title': 'Система Fan ID станет обязательной для посещения матчей РПЛ в Екатеринбурге',
#   'url': 'https://www.kommersant.ru/doc/5423401',
#   'published_date': datetime.datetime(2022, 6, 22, 7, 46),
#   'text': 'С начала сезона-2022/23 использование персонифицированной карты болельщика (Fan ID) станет обязательным для посещения матчей Российской Премьер-лиги (РПЛ), которые будут проходить на «Екатеринбург Арене». Об этом сообщили в пресс-службе лиги. Также систему Fan ID введут на стадионах «Нижний Новгород», «Ростов Арена», «Солидарность Самара Арена» и «Фишт». Остальные стадионы подключатся к проекту во второй части сезона.'},
#  {'description': '',
#   'news_id': '5423379',
#   'title': 'Контур торпедного катера «Комсомолец» выложили из свечей в Тюмени',
#   'url': 'https://www.kommersant.ru/doc/5423379',
#   'published_date': datetime.datetime(2022, 6, 22, 5, 34),
#   'text': 'Вечером 21 июня на Исторической площади Тюмени из свечей выложили контур торпедного катера «Комсомолец». Свечи зажгли в память о солдатах Великой Отечественной войны, в рамках Всероссийской акции «Огненные картины войны». По словам мэра Романа Кухарука, изображение катера было составлено из 1,9 тыс. свечей.'},
#  {'description': '',
#   'news_id': '5423375',
#   'title': 'Более 4,5 тыс. человек вышли на акцию «Свеча памяти» в Екатеринбурге',
#   'url': 'https://www.kommersant.ru/doc/5423375',
#   'published_date': datetime.datetime(2022, 6, 22, 4, 33),
#   'text': 'В Екатеринбурге более 4,5 тыс. человек вышли вечером 21 июня на Всероссийскую гражданскую акцию «Свеча памяти». В этот день люди зажигают свечи в память о 27 млн сограждан, погибших в Великой Отечественной войне.  Екатеринбуржцы прошли колонной по проспекту Ленина от Дома Севастьянова до площади 1905 года с зажженными свечами, а по окончании шествия выстроились в слово «Помним».'},
#  {'description': 'Александр Оглоблин закрыл почти все супермаркеты в Екатеринбурге',
#   'news_id': '5423217',
#   'title': 'Еле «Елисей»',
#   'url': 'https://www.kommersant.ru/doc/5423217',
#   'published_date': datetime.datetime(2022, 6, 22, 4, 10),
#   'text': 'Бизнесмен Александр Оглоблин закрыл почти все супермаркеты «Елисей» в Екатеринбурге, сократив количество магазинов с 22-х в 2019 году до одного в июне 2022-го. Сейчас он намерен развивать имеющиеся у него гастрономы и фабрику-кухню. По мнению экспертов, региональные сети не выдерживают конкуренции с федеральными, в том числе из-за отсутствия финансовой возможности работать в формате жесткого дискаунтера. Аналитики полагают, что тренд на закрытие магазинов региональных сетей сохранится, а бизнес в ряде случаев будет переориентирован на сдачу помещений магазинов в аренду.В Екатеринбурге остался один магазин торговой сети «Елисей» на улице Шейнкмана, 7, а также четыре гастронома «Елисейский». Еще в конце прошлого года в городе работало семь супермаркетов, а в 2019 в уральской столице насчитывалось 22 точки. Как ранее объяснял владелец сети Александр Оглоблин, он закрывает супермаркеты из-за их низкой рентабельности и высокой конкуренции дискаунтеров.«Фактически у нас осталось четыре гастронома — магазин "Елисей" на улице Юмашева мы считаем гастрономом, потому что продукты готовятся на месте, и там представлен расширенный ассортимент, а также остался небольшой магазинчик на Шейнкмана, 7»,—рассказал «Ъ-Урал» господин Оглобин. Отметим, что помещение супермаркета на Бажова, где ранее работал «Елисей», бизнесмен сдал в аренду сети «Монеточка». Оставшиеся помещения, которые находятся в собственности, компания также сдала в аренду.  «Несмотря на все кризисы и спецоперации, есть тренд питаться правильно. Можно самим (производителям) пытаться придумывать рецептуру, экспериментировать, смотреть, что продается, что нет, а можно было воспользоваться готовым и успешным проектом, что мы и сделали»,— добавил господин Оглоблин.Участники рынка отмечают, что из-за высокой конкуренции с федеральными игроками рынок регионального ритейла может опустеть. По мнению инвестиционного стратега «БКС Мир инвестиций» Александра Бахтина региональные сети не выдерживают конкуренции с федеральными сетями по целому ряду причин. «За счет эффекта масштабов, за счет возможностей получить скидки от оптовиков, и, соответственно, сократить расходы, федеральные сети выигрывают у более мелких сетей в рентабельности и постепенно замещают их на региональных рынках. Полагаем, что этот тренд будет продолжаться. Региональные сети будут постепенно отказываться от нерентабельных точек и форматов, при этом в ряде случаев, переориентируясь на получение прибыли с арендных платежей»,— рассказал он. Гендиректор «Infoline-Аналитики» Михаил Бурмистров отметил, что сейчас крупные региональные ритейлеры активно развивают формат жестких дискаунтеров, однако для сетей с выручкой несколько миллиардов рублей и меньше это слишком сложный и инвестиционно-емкий проект.'},
#  {'description': 'Возбуждено дело о хищении средств структуры «Роскосмоса»',
#   'news_id': '5423270',
#   'title': 'Строители сработали на космическом уровне',
#   'url': 'https://www.kommersant.ru/doc/5423270',
#   'published_date': datetime.datetime(2022, 6, 21, 20, 55),
#   'text': 'В Свердловской области возбудили уголовное дело о мошенничестве с федеральными деньгами, выделенными на развитие космической отрасли и оборонного комплекса. По сведениям «Ъ-Урал», к мошенничеству может быть причастен сотрудник Научно-исследовательского института машиностроения, входящего в «Роскосмос». По версии следствия, он подписывал документы о завершении генподрядчиками — компанией «Космосавиаспецстрой» и ФГУП «Спецстройсервис» — строительных работ, которые фактически не были завершены. Предварительно сумма ущерба составляет более 100 млн руб.О возбуждении уголовного дела о мошенничестве с денежными средствами в Научно-исследовательском институте машиностроения (НИИМаш) сообщил источник «Ъ-Урал», знакомый с деталями расследования. По словам собеседника, дело возбуждено по ч. 4 ст. 159 УК РФ (мошенничество, совершенное организованной группой либо в особо крупном размере), фигурантов в нем пока нет. Следствие считает, что сотрудник НИИМаш подписывал документы о завершении генеральными подрядчиками строительных работ в рамках федеральных целевых программ (ФЦП) по развитию космической отрасли и гособоронзаказу, которые фактически выполнены не были. Предварительно сумма ущерба превышает 100 млн руб., добавил источник.При этом, по его словам, «стоимость невыполненных работ по программам несопоставима с мероприятиями, реализованными предприятием вне проектной документации». «К тому же на АО “НИИМаш” отсутствуют документы, подтверждающие законность перераспределения денежных средств при реализации ФЦП»,— утверждает он.Речь идет о «Федеральной космической программе России на 2006–2015 годы» и программе «Развитие оборонно-промышленного комплекса РФ на 2011–2020 годы». По предварительным оценкам, в рамках проекта по первой программе генеральный подрядчик должен был выполнить 18 наименований работ, среди которых реконструкция воздухозаборной станции, строительство и ремонт аварийных сливов, сетей водоснабжения и другого. Общая стоимость работ по программе оценивается в 47,2 млн руб., генеральным подрядчиком выступало ООО «Космосавиаспецстрой».Генподрядчиком по программе развития ОПК указано ФГУП «Спецстройсервис». По госконтракту предприятие должно было выполнить для НИИМаш 24 наименования работ, в основном это реконструкция и перевооружение площадок и корпусов. Стоимость контракта со «Спецстройсервисом» составила 110,7 млн руб.Проверка проводилась сотрудниками нескольких силовых ведомств, сейчас материалы переданы в главное следственное управление одного из них, добавил собеседник «Ъ-Урал». В пресс-службе НИИМаш заявили, что не будут комментировать информацию, пока ведется расследование. От официальных комментариев воздержались и свердловские управления Следственного комитета РФ, МВД и ФСБ.ООО «Космосавиаспецстрой» было зарегистрировано в Москве в 2002 году, следует из данных системы «СПАРК-Интерфакс». Компания специализировалась на строительстве жилых и нежилых зданий, в системе содержится информация о нескольких госконтрактах, заключенных с «Роскосмосом» и аффилированными с ним предприятиями. Весной 2019 года ТАСС сообщал, что одного из бывших гендиректоров «Космосавиаспецстроя» — Григория Вайсмана — объявили в международный розыск по обвинению в хищении 711 млн руб. при выполнении госконтракта с НПП «Исток» имени Шокина. Контракт предполагал техническое переоборудование производства СВЧ-субмодулей. Тогда же адвокат господина Вайсмана сообщал, что его подзащитный покинул Россию. В сентябре 2021 года юрлицо «Космосавиаспецстроя» было ликвидировано вследствие банкротства.Бывший генеральный директор «Спецстройсервиса» Андрей Ярцев тоже становился фигурантом уголовного дела о злоупотреблении полномочиями. В 2020 году суд приговорил его к трем годам колонии общего режима, установив, что Андрей Ярцев способствовал тому, что его предприятие закупило некачественные аэродромные плиты по завышенным ценам. Ущерб, нанесенный предприятию его действиями, оценили в 58,6 млн руб.'},
#  {'description': 'Гордума единогласно приняла отчет мэра Екатеринбурга за 2021 год',
#   'news_id': '5423201',
#   'title': 'Алексей Орлов и депутаты обменялись цифрами',
#   'url': 'https://www.kommersant.ru/doc/5423201',
#   'published_date': datetime.datetime(2022, 6, 21, 20, 20),
#   'text': 'Глава Екатеринбурга Алексей Орлов во вторник, 21 июня, представил на заседании гордумы отчет о своей работе за 2021 год — его первый год в должности мэра. По его словам, этот период в истории города был удачным: Екатеринбург занимает лидирующие позиции среди городов-миллионников по зарплате, количеству строящегося жилья, товарообороту. Депутаты уточнили отдельные моменты отчета, «договорились» с главой о дальнейших действиях и единогласно одобрили работу Орлова в прошлом году. За ходом заседания наблюдал корреспондент «Ъ-Урал» Артем Рябов.Во вторник, 21 июня, на очередном заседании думы Екатеринбурга мэр Алексей Орлов отчитался перед депутатами о результатах деятельности администрации города в 2021 году. Для мэра это был первый полноценный отчет — Алексей Орлов возглавил муниципалитет в декабре 2020-го в статусе и.о., а в феврале 2021 года стал полноценным мэром. Господин Орлов сразу поблагодарил депутатов за то, что они не мешали эффективно работать. Так, с первых дней своей работы в качестве градоначальника он начал отстранять их от принятия ключевых решений. Например, гордума позволила ему самостоятельно перераспределять функционал между своими заместителями. «Полагаю, что принятые решения, безусловно, положительно сказались на рабочем процессе»,— улыбнулся Алексей Орлов. Перед перечислением показателей успешности уральской столицы мэр напомнил, что в минувшие два года темпы развития Екатеринбурга серьезно снижались из-за пандемии коронавируса. «Она оказала значительное влияние на всю мировую экономику. Но сейчас можно отметить, что мы справились, вернулись на рельсы развития»,— заявил Алексей Орлов. После стремительного роста безработицы ситуацию на рынке труда удалось нормализовать. Численность зарегистрированных безработных за прошлый год сократилась почти в 12 раз и составила 3748 человек. Уровень регистрируемой безработицы составил 0,5% от экономически активного населения. По росту зарплаты и розничному товарообороту Екатеринбург продолжает занимать первые места — в 2021 году уступил по зарплате только Красноярску, где есть районный коэффициент. Так, за 2021 год средняя зарплата работников крупных и средних организаций Екатеринбурга выросла до 63 893 руб., а это на 10,5%  больше, чем годом ранее. «Большой вклад в этот процесс внесли крупные работодатели, которые в трудный период направляли часть прибыли на повышение жалования своих сотрудников»,— отметил мэр Екатеринбурга. По его словам, за 2021 год объем отгруженных товаров крупных и средних промышленных предприятий города увеличился на 11% и составил 509 млрд руб., а объем интернет-торговли вырос в пять раз. Оборот крупных и средних предприятий по итогам 2021 года составил 3 трлн руб. и 77 млрд руб. соответственно. Благодаря действиям властей удалось не допустить остановки производств. Продолжился рост объемов промышленного производства. Оборот розничной торговли по полному кругу предприятий, несмотря на рост цен, увеличился на 1,7% и оценивается в 928 млрд руб. «Екатеринбургская нефть» — стройка. В этой сфере, по словам Алексея Орлова, все было устойчиво. «Совместными усилиями девелоперов и городских властей в прошлом году, вопреки пандемии, вновь был поставлен рекорд. Мы ввели порядка 1,5 млн кв. м жилья»,— в голосе зазвучали нотки гордости, а взгляд устремился на присутствовавшего вице-мэра по строительству Рустама Галямова. Тот смутился и опустил глаза. «В прошлом году градостроительные полномочия вновь перешли от области к муниципалитету, это позволит более эффективно взаимодействовать с застройщиками и положительно скажется на разработке Генплана Екатеринбурга до 2045 года»,— добавил глава Екатеринбурга.За 2021 год по заданию муниципалитета было построено шесть детсадов и четыре школы, а количество учащихся увеличилось на 8,3 тыс. человек и достигло 180 тысяч. Комментируя итоги развития ЖКХ, глава Екатеринбурга сообщил, что за год в городе было заменено 712 лифтов, 162 из них — за счет средств областного и муниципального бюджетов. Реализация инвестпр ...

# %%
with open('kommersant', 'wb') as f:
    pickle.dump(news, f)

# %%
news[-1]
# Out:
# {'description': '',
#  'news_id': 5369059,
#  'title': 'Запрет на посещение лесов в Тюменской области продлили до 16 июня',
#  'url': 'https://www.kommersant.ru/doc/5369059',
#  'published_date': Timestamp('2022-05-26 11:55:46'),
#  'text': 'Для жителей Тюменской области до 16 июня продлили запрет на посещение лесов. Соответствующее постановление подписал губернатор Александр Моор, передает информационный центр регионального правительства в telegram-канале. Согласно постановлению, тюменцам запрещено разводить костры, готовить пищу на открытом огне и углях, проводить пожароопасные работы и использовать пиротехнические изделия. Кроме того, в регионе усилили патрулирование лесов.  В случае обнаружения пожара необходимо сообщить о нем по номерам: 8-800-100-94-00, 112.'}
