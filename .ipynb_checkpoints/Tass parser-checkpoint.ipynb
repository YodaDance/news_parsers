# %% [markdown]
# ## Importing libs

# %%
import time
import numpy as np
import pandas as pd
import os

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import json

# %% [markdown]
# ### Set up selenium browser

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('headless')                        
driver = webdriver.Chrome(executable_path='./chromedriver', options=options)

# %% [markdown]
# ## Web scraping TASS

# %%
def get_content(driver: selenium.webdriver, api: str) -> json:
    '''Open a link by selenium webdriver, scrap the page and returns result with proposed news in json format'''
    driver.get(api) # открываем ссылку
    time.sleep(3) # даем прогрузиться
    
    page_source = driver.page_source # берем страницу
    soup = BeautifulSoup(page_source, 'html.parser') # парсим
    data = json.loads(soup.body.text) # достаем текст и превращаем в формат json
    
    return data


def update_news(news: list, data: json):
    '''Download news from Tass ural (/ural-news) and add to the existing list of news
    '''
    new_news = [] # список всех распарсенных новостей
    for item in data['result']: # идем по каждой новости
        cur_news = {} 
        cur_news['conmposite_id'] = item['composite_id']
        cur_news['title'] = item['title']
        cur_news['subtitle'] = item['subtitle']
        cur_news['lead'] = item['lead']
        cur_news['url'] = 'https://tass.ru' + item['url']
        cur_news['rubrics'] = []
        for rubric in item['rubrics']:
            cur_news['rubrics'].append(rubric['name'])
        cur_news['tags'] = []
        for tag in item['tags']:
            cur_news['tags'].append(tag['name'])
        cur_news['es_updated_dt'] = item['es_updated_dt']
        cur_news['published_date'] = item['es_updated_dt'].split('T')[0]
        new_news.append(cur_news)
        
    news.extend(new_news) # расширяем существующий список новыми новостями
    pass

# %%
# загружаем новости со стартовой страницы
api = 'https://tass.ru/tbp/api/v1/content?limit=18&offset=0&lang=ru&rubrics=/ural-news&sort=-es_updated_dt'
data = get_content(driver, api)

# %%
data['result'][0] # так выглядит новость
# Out:
# {'id': 14971095,
#  'composite_id': '14971095',
#  'type': 'news',
#  'status': 'published',
#  'title': 'В Екатеринбурге возбудили дело после того, как мужчина выбросил сына из окна',
#  'subtitle': '',
#  'lead': 'По данным следствия, отец был пьян',
#  'url': '/proisshestviya/14971095',
#  'lang': 'ru',
#  'urgency': 'normal',
#  'main_media': {'gallery': None, 'image': None, 'video': None},
#  'main_rubric_id': 27,
#  'rubrics': [{'id': 27,
#    'name': 'Происшествия',
#    'url': '/proisshestviya',
#    'type': 'rubric'},
#   {'id': 4731,
#    'name': 'Новости Урала',
#    'url': '/ural-news',
#    'type': 'rubric'}],
#  'tags': [{'id': 3929, 'name': 'Россия', 'url': '/rossiya'},
#   {'id': 8974,
#    'name': 'Свердловская область',
#    'url': '/sverdlovskaya-oblast'}],
#  'published_dt': '2022-06-20T07:12:11',
#  'publish_updated_dt': '2022-06-20T07:12:11',
#  'updated_dt': '2022-06-20T07:12:11',
#  'es_updated_dt': '2022-06-20T07:12:11.030087',
#  'meta_title': 'В Екатеринбурге возбудили дело после того, как мужчина выбросил сына из окна  - ТАСС',
#  'meta_description': 'По данным следствия, отец был пьян',
#  'author': ' ЕКАТЕРИНБУРГ 20, июня. /ТАСС',
#  'authors': [{'id': None,
#    'url': None,
#    'name': ' ЕКАТЕРИНБУРГ 20, июня. /ТАСС',
#    'image': None,
#    'role': None,
#    'is_expert': False}],
#  'technical_caption': '',
#  'options': {'is_online': None,
#   'is_live': None,
#   'is_flash': False,
#   'is_verified_by_tass': False,
#   'is_explained_by_tass': False,
#   'card_quantity': None,
#   'sponsor_type': None,
#   'hide_main_photo': False},
#  'stream': {'is_video_streaming': False,
#   'rtmp': '',
#   'smil': '',
#   'm3u8': '',
#   'copyright': '',
#   'description': None}}

# %%
news = []
update_news(news, data)

# %%
news[0] # так выглядит каждая новость
# Out:
# {'conmposite_id': '14971095',
#  'title': 'В Екатеринбурге возбудили дело после того, как мужчина выбросил сына из окна',
#  'subtitle': '',
#  'lead': 'По данным следствия, отец был пьян',
#  'url': 'https://tass.ru/proisshestviya/14971095',
#  'rubrics': ['Происшествия', 'Новости Урала'],
#  'tags': ['Россия', 'Свердловская область'],
#  'es_updated_dt': '2022-06-20T07:12:11.030087',
#  'published_date': '2022-06-20'}

# %%
pd.DataFrame.from_records(news) # можно сделать датафреймом
# Out:
#    conmposite_id                                              title subtitle  \
# 0       14971095  В Екатеринбурге возбудили дело после того, как...
# 1       14970709  В УрФУ разработают лекарства с благородными ме...
# 2       14970605  Автобус столкнулся с грузовиком в Челябинской ...
# 3       14970533  Автомобиль сбил двух подростков в одном из сел...
# 4       14969993  ЯНАО, Москва и Магаданская область возглавили ...
# 5       14969787  Площадь лесных пожаров в России выросла на 7 т...
# 6       14968873  "Новые люди" выдвинули депутата Госдумы Демина...
# 7       14968819  УрФУ планирует увековечить память Бурбулиса со...
# 8       14968359  В Екатеринбурге из-за пожара в "Леруа Мерлен" ...
# 9       14967945  Замначальника полиции УМВД по Магнитогорску ар...
# 10      14966223  Пожар на территории птицефабрики в Челябинской...
# 11      14966253  Золотодобывающее предприятие в Таджикистане по...
# 12      14965763  В Челябинской области при пожаре на птицефабри...
# 13      14965241  В Алтайском крае проведут работы по берегоукре...
# 14      14965015  Число возводимых ФАПов в Свердловской области ...
# 15      14964641  В Кировской области заявили, что перспективы о...
# 16      14964457  Путин по ВКС откроет медцентры в нескольких ре...
# 17      14964293  На соцподдержку жителей Свердловской области н...
#
#                                                  lead  \
# 0                  По данным следствия, отец был пьян
# 1   Специалисты вуза также займутся разработкой пр...
# 2                Информация о пострадавших уточняется
# 3                  Пострадавших доставили в больницу
# 4                     Всего в рейтинг вошел 41 регион
# 5   За прошлые сутки в стране ликвидировали 41 воз...
# 6                          Выборы пройдут 11 сентября
# 7                     Политик умер на 77-м году жизни
# 8              В результате пожара никто не пострадал
# 9   По версии следствия, он получил деньги за то, ...
# 10                                   Пострадавших нет
# 11  Торговый представитель РФ в Таджикистане Евген...
# 12               Площадь пожара оценили в 2 300 кв. м
# 13   На работы потребуется финансирование в размер...
# 14  В регионе хотят построить еще 23 фельдшерско-а...
# 15  По словам врио губернатора Александра Соколова...
# 16  Всего в субботу планируется открыть 19 медицин...
# 17  Расходная часть региональной казны увеличится,...
#
#                                         url  \
# 0   https://tass.ru/proisshestviya/14971095
# 1       https://tass.ru/obschestvo/14970709
# 2   https://tass.ru/proisshestviya/14970605
# 3   https://tass.ru/proisshestviya/14970533
# 4        https://tass.ru/ekonomika/14969993
# 5   https://tass.ru/proisshestviya/14969787
# 6         https://tass.ru/politika/14968873
# 7       https://tass.ru/obschestvo/14968819
# 8   https://tass.ru/proisshestviya/14968359
# 9   https://tass.ru/proisshestviya/14967945
# 10  https://tass.ru/proisshestviya/14966223
# 11       https://tass.ru/ekonomika/14966253
# 12  https://tass.ru/proisshestviya/14965763
# 13      https://tass.ru/obschestvo/14965241
# 14      https://tass.ru/obschestvo/14965015
# 15       https://tass.ru/ekonomika/14964641
# 16      https://tass.ru/obschestvo/14964457
# 17       https://tass.ru/ekonomika/14964293
#
#                                               rubrics  \
# 0                       [Происшествия, Новости Урала]
# 1                   [Общество, Новости Урала, Сибирь]
# 2                       [Происшествия, Новости Урала]
# 3                       [Происшествия, Новости Урала]
# 4   [Общество, Экономика и бизнес, Северо-Запад, Н...
# 5   [Происшествия, Северо-Запад, Новости Урала, Си...
# 6      [Политика, Новости Урала, Внутренняя политика]
# 7                           [Общество, Новости Урала]
# 8                       [Происшествия, Новости Урала]
# 9                       [Происшествия, Новости Урала]
# 10                      [Происшествия, Новости Урала]
# 11                [Экономика и бизнес, Новости Урала]
# 12                      [Происшествия, Новости Урала]
# 13       [Общество, Новости Урала, Сибирь, ПМЭФ-2022]
# 14                          [Общество, Новости Урала]
# 15     [Экономика и бизнес, Новости Урала, ПМЭФ-2022]
# 16                  [Общество, Новости Урала, Сибирь]
# 17                [Экономика и бизнес, Новости Урала]
#
#                                                  tags  \
# 0                      [Россия, Свердловская область]
# 1                      [Россия, Свердловская область]
# 2                       [Россия, Челябинская область]
# 3                      [Россия, Свердловская область]
# 4                                            [Россия]
# 5   [Россия, Лесные пожары в России, Камчатский кр...
# 6                      [Россия, Свердловская область]
# 7                      [Россия, Свердловская область]
# 8                      [Россия, Свердловская область]
# 9                       [Россия, Челябинская область]
# 10                      [Россия, Челябинская область]
# 11                              [Таджикистан, Россия]
# 12                      [Россия, Челябинская область]
# 13                [Россия, Алтайский край, ПМЭФ-2022]
# 14  [Путин, Владимир Владимирович, Куйвашев, Евген...
# 15             [Россия, Кировская область, ПМЭФ-2022]
# 16             [Путин, Владимир Владимирович, Россия]
# 17                     [Россия, Свердловская область]
#
#                  es_updated_dt published_date
# 0   2022-06-20T07:12:11.030087     2022-06-20
# 1   2022-06-20T06:10:48.846746     2022-06-20
# 2   2022-06-20T05:51:39.747223     2022-06-20
# 3   2022-06-20T05:27:31.607031     2022-06-20
# 4   2022-06-20T00:39:00.676491     2022-06-20
# 5   2022-06-19T23:10:03.121547     2022-06-19
# 6   2022-06-19T16:55:02.352722     2022-06-19
# 7   2022-06-19T16:10:52.817181     2022-06-19
# 8   2022-06-19T12:46:32.706099     2022-06-19
# 9   2022-06-19T10:54:55.165014     2022-06-19
# 10  2022-06-18T19:26:21.123423     2022-06-18
# 11  2022-06-18T19:26:17.044375     2022-06-18
# 12  2022-06-18T17:27:00.336024     2022-06-18
# 13  2022-06-18T15:25:36.429728     2022-06-18
# 14  2022-06-18T14:29:06.374643     2022-06-18
# 15  2022-06-18T13:42:21.915387     2022-06-18
# 16  2022-06-18T12:13:00.386204     2022-06-18
# 17  2022-06-18T11:49:49.055312     2022-06-18

# %%
i = 0
while True:
    time.sleep(10)
    i += 1
    last_es_updated_dt = news[-1]['es_updated_dt']
    iter_api = f'https://tass.ru/tbp/api/v1/content?limit=15&last_es_updated_dt={last_es_updated_dt}&lang=ru&rubrics=/ural-news&sort=-es_updated_dt'
    data = get_content(driver, iter_api)
    update_news(news, data)
    if i == 100:
        pd.Series(news).to_csv(path_or_buf='tass.csv', header=False, index=False)
        i = 0

# %%
driver.close()

# %%
len(news)
# Out:
# 12888

# %%
pd.Series(news).to_csv(path_or_buf='tass.csv', header=False, index=False)
